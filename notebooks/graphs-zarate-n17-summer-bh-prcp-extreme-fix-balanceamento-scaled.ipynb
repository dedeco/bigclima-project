# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import shutil
from sklearn.utils import shuffle

# %% [markdown]
# # Importando base de dados

# %% [markdown]
# <p>Base com todos os dados do sudeste</p>

# %%
df = pd.read_csv('../data/sudeste.csv',low_memory=False)
print (len(df))
# Out:
# 9779168

# %%
df = df[df['mo'].isin([1,2,3,12])] #  somente meses do verão DEZ a MAR
print (len(df))
df.sample(3)
# Out:
# 3206856
#          wsid          wsnm   elvt        lat        lon  inme  \
# 4444706   352       BURITIS  894.0 -15.524262 -46.435536  A544
# 6584238   381   TERESÓPOLIS  991.0 -22.448922 -42.987146  A618
# 6826431   384  VILA MILITAR   30.0 -22.861322 -43.411410  A621
#
#                    city prov                 mdct        date  ...   tmin  \
# 4444706         Buritis   MG  2012-12-18 18:00:00  2012-12-18  ...   32.5
# 6584238     Teresópolis   RJ  2013-03-17 22:00:00  2013-03-17  ...   19.8
# 6826431  Rio de Janeiro   RJ  2013-03-14 07:00:00  2013-03-14  ...   25.7
#
#          dewp  dmax  dmin  hmdy  hmax  hmin  wdsp   wdct  gust
# 4444706  15.0  30.6   9.4  32.0  37.0  25.0   1.3  230.0   5.9
# 6584238  19.3  19.5  18.8  97.0  97.0  96.0   0.5   91.0   2.2
# 6826431  23.2  25.2  22.8  87.0  88.0  86.0   0.4  106.0   2.3
#
# [3 rows x 31 columns]

# %%
df = df.sort_values(['wsid', 'mdct'])
df = df.reset_index(drop=True)

# %%
#df = df[(df['lat'].between(-20.5,-19.0, inclusive=True)) & 
#        (df['lon'].between(-44.5,-43.0, inclusive=True))]

# %%
df = df[df['wsid']==329]
print (len(df))
# Out:
# 29112

# %%
df.head(4)
# Out:
#         wsid                  wsnm   elvt        lat        lon  inme  \
# 816792   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816793   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816794   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816795   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
#
#                   city prov                 mdct        date  ...   tmin  \
# 816792  Belo Horizonte   MG  2006-12-01 00:00:00  2006-12-01  ...   20.7
# 816793  Belo Horizonte   MG  2006-12-01 01:00:00  2006-12-01  ...   20.9
# 816794  Belo Horizonte   MG  2006-12-01 02:00:00  2006-12-01  ...   20.9
# 816795  Belo Horizonte   MG  2006-12-01 03:00:00  2006-12-01  ...   20.7
#
#         dewp  dmax  dmin  hmdy  hmax  hmin  wdsp   wdct  gust
# 816792  20.5  20.4  20.2  99.0  99.0  98.0   1.0  121.0   2.6
# 816793  20.6  20.7  20.5  98.0  99.0  98.0   1.2  146.0   2.0
# 816794  20.6  20.5  20.3  98.0  98.0  98.0   0.5  309.0   2.0
# 816795  20.5  20.6  20.3  98.0  98.0  98.0   NaN  356.0   0.9
#
# [4 rows x 31 columns]

# %% [markdown]
# # Pré-processamento

# %% [markdown]
# <h3>Dados ausentes</h3>

# %%
missing_values_count = (df.isnull().sum()/len(df))*100

# %%
missing_values_count[missing_values_count > 0.1]
# Out:
# prcp    86.723688
# gbrd    41.872767
# wdsp     5.021984
# gust     1.329349
# dtype: float64

# %% [markdown]
# <p> A variável gbbr(radiação global) apresenta massivamente números nulos e não pode ser recuperada. Vamos retirar esta variável.</p>

# %%
df = df.drop('gbrd',1)

# %% [markdown]
# <p>Para as precipitações nulas foi inputado 0.0 mm. Também para o vento e rajada de vento.</p>

# %%
CAN_BE_NULL = ['wdsp','prcp','gust']

# %%
for v in CAN_BE_NULL:
    df[v] = df[v].fillna(0.0)

# %%
missing_values_count = (df.isnull().sum()/len(df))*100
miss = missing_values_count[missing_values_count > 0]
miss
# Out:
# Series([], dtype: float64)

# %% [markdown]
# <p>Alguns campos estão com pouquissimos valores nulos.</p>

# %%
DES = ['wsid','wsnm','elvt','lat','lon','inme','city','prov','mdct','date','yr','mo','da','hr']

# %%
V = [x for x in df.columns if x not in DES]
#df[V].describe().T

# %% [markdown]
# <p><b>PRONTO! Dados recuperados!</b> Agora vamos a etapa de limpeza</p>

# %% [markdown]
# <h3>Limpeza dos dados</h3>

# %%
backup_df = df.copy

# %% [markdown]
# <p>Alguns campos podem ser nulos</p>

# %%
cols = list(df.columns)

COLS_BE_NULL = ['prcp','wdsp','gust'] + DES
for v in COLS_BE_NULL:
    if v in cols:
        cols.remove(v)
cols
# Out:
# ['stp',
#  'smax',
#  'smin',
#  'temp',
#  'tmax',
#  'tmin',
#  'dewp',
#  'dmax',
#  'dmin',
#  'hmdy',
#  'hmax',
#  'hmin',
#  'wdct']

# %%
df[V].describe().T
# Out:
#         count        mean        std  min    25%    50%    75%    max
# prcp  29112.0    0.380702   2.269639  0.0    0.0    0.0    0.0   78.4
# stp   29112.0  908.517257  89.239876  0.0  915.8  917.4  918.9  924.2
# smax  29112.0  908.700110  89.580653  0.0  916.0  917.7  919.1  924.3
# smin  29112.0  908.207399  89.532850  0.0  915.5  917.2  918.6  924.2
# temp  29112.0   23.124210   3.927019  0.0   20.7   22.7   25.7   33.9
# tmax  29112.0   17.124471   2.524743  0.0   16.1   17.5   18.7   22.6
# tmin  29112.0   23.777490   4.147014  0.0   21.1   23.4   26.6   35.1
# dewp  29112.0   17.726384   2.565495  0.0   16.7   18.0   19.2   23.6
# dmax  29112.0   22.487236   3.703314  0.0   20.3   22.1   24.8   32.4
# dmin  29112.0   16.565873   2.555016  0.0   15.5   17.0   18.2   21.6
# hmdy  29112.0   70.242065  17.518920  0.0   58.0   71.0   84.0   99.0
# hmax  29112.0   73.268515  16.719424  0.0   62.0   75.0   87.0   99.0
# hmin  29112.0   67.174430  18.149105  0.0   54.0   68.0   81.0   98.0
# wdsp  29112.0    2.008983   1.141264  0.0    1.2    2.0    2.8   10.2
# wdct  29112.0  127.354733  97.312586  0.0   69.0   97.0  131.0  360.0
# gust  29112.0    5.229960   2.342046  0.0    3.7    5.3    6.8   25.0

# %%
df[cols] = df[cols].replace({0.0:np.nan})

# %%
print (len(df))
df  = df.dropna()
print (len(df))
# Out:
# 29112
# 28832

# %% [markdown]
# <p>Verificando os mínimos e máximos por região.</p>

# %%
df[V].describe().T
# Out:
#         count        mean        std    min    25%    50%    75%    max
# prcp  28832.0    0.384399   2.280322    0.0    0.0    0.0    0.0   78.4
# stp   28832.0  917.276554   2.343445  906.5  915.8  917.4  918.9  924.2
# smax  28832.0  917.524889   2.322062  906.7  916.1  917.7  919.1  924.3
# smin  28832.0  917.027393   2.350573  906.4  915.6  917.2  918.6  924.2
# temp  28832.0   23.347035   3.219508   15.3   20.7   22.8   25.7   33.9
# tmax  28832.0   17.289442   1.892367    6.6   16.1   17.5   18.7   22.6
# tmin  28832.0   24.008404   3.438123   16.4   21.2   23.4   26.6   35.1
# dewp  28832.0   17.898533   1.887954    6.7   16.7   18.1   19.2   23.6
# dmax  28832.0   22.705619   2.981447   15.0   20.3   22.1   24.9   32.4
# dmin  28832.0   16.726752   1.974954    5.3   15.6   17.0   18.2   21.6
# hmdy  28832.0   70.919360  16.182016   24.0   59.0   72.0   84.0   99.0
# hmax  28832.0   73.980057  15.152960   27.0   63.0   75.0   87.0   99.0
# hmin  28832.0   67.826790  16.980576   20.0   55.0   68.0   82.0   98.0
# wdsp  28832.0    2.028323   1.129516    0.0    1.2    2.1    2.8   10.2
# wdct  28832.0  128.578940  96.964446    1.0   71.0   97.0  132.0  360.0
# gust  28832.0    5.280751   2.295698    0.0    3.7    5.3    6.8   25.0

# %% [markdown]
# <p>Algumas regras:</p>
# <ul>
#    <li>Max > Min: para temperatura, humidade, pressão e ponto de orvalho</li>
#    <li>Mínima para região é possivel?</li>
#    <li>Máxima para região é possivel?</li>
# </ul>

# %% [markdown]
# <p>Vamos a temperatura máxima e mínima</p>

# %%
x = df[(df['tmin'] > df['tmax'])]
print ('tmin>tmax',x)
x = df[(df['hmin'] > df['hmax'])]
print ('hmin>hmax',x)
x = df[(df['smin'] > df['smax'])]
print ('smin>smax',x)
x = df[(df['dmin'] > df['dmax'])]
print ('dmin>dmax',x)
# Out:
# tmin>tmax         wsid                  wsnm   elvt        lat        lon  inme  \
# 816792   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816793   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816794   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816795   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816796   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816797   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816798   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816799   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816800   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816801   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816802   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816803   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816804   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816805   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816806   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816807   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816808   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816809   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816810   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816811   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816812   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816813   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816814   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816815   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816816   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816817   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816818   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816819   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816820   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 816821   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# ...      ...                   ...    ...        ...        ...   ...
# 845874   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845875   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845876   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845877   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845878   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845879   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845880   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845881   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845882   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845883   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845884   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845885   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845886   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845887   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845888   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845889   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845890   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845891   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845892   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845893   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845894   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845895   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845896   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845897   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845898   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845899   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845900   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845901   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845902   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
# 845903   329  BELO HOR. (PAMPULHA)  854.0 -19.883945 -43.969397  A521
#
#                   city prov                 mdct        date  ...   tmin  \
# 816792  Belo Horizonte   MG  2006-12-01 00:00:00  2006-12-01  ...   20.7
# 816793  Belo Horizonte   MG  2006-12-01 01:00:00  2006-12-01  ...   20.9
# 816794  Belo Horizonte   MG  2006-12-01 02:00:00  2006-12-01  ...   20.9
# 816795  Belo Horizonte   MG  2006-12-01 03:00:00  2006-12-01  ...   20.7
# 816796  Belo Horizonte   MG  2006-12-01 04:00:00  2006-12-01  ...   20.7
# 816797  Belo Horizonte   MG  2006-12-01 05:00:00  2006-12-01  ...   20.8
# 845895  19.7  25.8  17.7  60.0  66.0  56.0   2.8   90.0   6.9
# 845896  19.1  26.1  17.5  59.0  63.0  55.0   2.4  122.0   6.9
# 845897  19.4  26.3  17.4  58.0  62.0  54.0   1.7   90.0   4.9
# 845898  19.1  27.2  16.6  52.0  59.0  50.0   1.5   39.0   6.1
# 845899  18.5  26.4  17.2  58.0  60.0  52.0   2.8  100.0   5.7
# 845900  18.4  25.9  17.3  60.0  62.0  58.0   2.4   74.0   5.7
# 845901  18.0  25.1  17.3  62.0  63.0  58.0   2.4   98.0   5.7
# 845902  17.5  24.5  17.1  64.0  65.0  61.0   2.8  107.0   5.6
# 845903  17.5  24.2  17.0  65.0  65.0  64.0   2.8  118.0   5.6
#
# [28832 rows x 30 columns]
# hmin>hmax Empty DataFrame
# Columns: [wsid, wsnm, elvt, lat, lon, inme, city, prov, mdct, date, yr, mo, da, hr, prcp, stp, smax, smin, temp, tmax, tmin, dewp, dmax, dmin, hmdy, hmax, hmin, wdsp, wdct, gust]
# Index: []
#
# [0 rows x 30 columns]
# smin>smax Empty DataFrame
# Columns: [wsid, wsnm, elvt, lat, lon, inme, city, prov, mdct, date, yr, mo, da, hr, prcp, stp, smax, smin, temp, tmax, tmin, dewp, dmax, dmin, hmdy, hmax, hmin, wdsp, wdct, gust]
# Index: []
#
# [0 rows x 30 columns]
# dmin>dmax Empty DataFrame
# Columns: [wsid, wsnm, elvt, lat, lon, inme, city, prov, mdct, date, yr, mo, da, hr, prcp, stp, smax, smin, temp, tmax, tmin, dewp, dmax, dmin, hmdy, hmax, hmin, wdsp, wdct, gust]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# <h4>Outliers</h4>

# %% [markdown]
# <p>Usando boxplot para verificar se existem outliers</p>

# %%
sns.set_style("whitegrid")

# %% [markdown]
# <p>Pressão atmosférica</p>

# %%
sns.set(font_scale=2) 
def bp(var):
    fig, ax = plt.subplots()
    fig.set_size_inches(15, 8)
    #sns.boxplot(x='prov',y=var, data=df, ax=ax)
    ax = sns.distplot(df[var])
    ax2 = ax.twinx()
    sns.boxplot(x=df[var], ax=ax2)
    ax2.set(ylim=(-.5, 10))
    ax.set_title('Com outliers: ' + var)
def bp_sem(var):
    q = df[var].quantile(0.99)
    x_filt = df[df[var] < q]
    fig, ax = plt.subplots()
    fig.set_size_inches(15, 8)
    ax = sns.distplot(x_filt[var])    
    ax.set_title('Sem outliers: ' + var)

# %%
bp('stp')
# Out:
# /home/dedeco/envs/kaggle/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
bp_sem('stp')
# Out:
# /home/dedeco/envs/kaggle/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
bp('temp')
# Out:
# /home/dedeco/envs/kaggle/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
bp_sem('temp')
# Out:
# /home/dedeco/envs/kaggle/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
bp('wdsp')
# Out:
# /home/dedeco/envs/kaggle/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
bp_sem('wdsp')
# Out:
# /home/dedeco/envs/kaggle/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
bp('prcp')
# Out:
# /home/dedeco/envs/kaggle/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
bp_sem('prcp')
# Out:
# /home/dedeco/envs/kaggle/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <h3>Derivando novas variáveis (Feature engineering)</h3>

# %% [markdown]
# <p>Recuperando o backup do dataframe antes da limpeza dos nulos, pois preciso derivar as freatures primeiro.
# Assim, após a derivá-las, irei apagar os que não pode ser nulo. Esta etapa teve que ser feita de novo, por este motivo</p>

# %%
dfm = backup_df()

# %%
len(dfm)
# Out:
# 29112

# %%
dfm = dfm.drop('wdsp',1)
dfm = dfm.drop('wdct',1)
dfm = dfm.drop('gust',1)

# %% [markdown]
# <p>Conforme o Zarate orientou retirando o vento pois precisa ser modelado de forma diferente</p>

# %%
CLEAN = ['wsnm','inme','city','prov','date']
REMOVE = ['yr', 'mo', 'da', 'hr']
#REMOVE = ['wsid','yr', 'mo', 'da', 'hr']
for v in CLEAN + REMOVE:
    dfm = dfm.drop(v,1)
dfm.sample(5)
# Out:
#         wsid   elvt        lat        lon                 mdct  prcp    stp  \
# 835671   329  854.0 -19.883945 -43.969397  2013-01-28 15:00:00  12.8  919.7
# 834372   329  854.0 -19.883945 -43.969397  2012-12-05 12:00:00   0.0  919.8
# 836882   329  854.0 -19.883945 -43.969397  2013-03-20 02:00:00   0.0  919.4
# 822256   329  854.0 -19.883945 -43.969397  2008-03-16 16:00:00   0.0  920.2
# 841119   329  854.0 -19.883945 -43.969397  2015-01-13 15:00:00   0.0  919.3
#
#          smax   smin  temp  tmax  tmin  dewp  dmax  dmin  hmdy  hmax  hmin
# 835671  919.9  919.6  21.7  19.3  22.8  19.4  20.4  17.2  87.0  87.0  76.0
# 834372  919.8  919.6  24.6  15.2  24.9  15.5  23.3  14.3  56.0  59.0  53.0
# 836882  919.5  919.3  19.5  13.4  19.9  13.7  19.5  13.4  68.0  68.0  67.0
# 822256  921.2  920.2  24.9  19.2  25.1  19.7  23.3  17.6  71.0  76.0  66.0
# 841119  919.8  919.3  30.0  13.1  31.6  15.2  29.6  12.8  36.0  40.0  34.0

# %%
ws = dfm['wsid'].groupby(dfm['wsid']).count()
ws = list(ws.keys())
print (ws)
# Out:
# [329]

# %%
def df_derived_by_shift(df,lag=0,NON_DER=[]):
    df = df.copy()
    
    if not lag:
        return df
    
    cols ={}
    for i in range(1,lag+1):
        for x in list(df.columns):
            if x not in NON_DER:
                if not x in cols:
                    cols[x] = ['{}_{}'.format(x, i)]
                else:
                    cols[x].append('{}_{}'.format(x, i))
  
    for k,v in cols.items():
        columns = v
        dfn = pd.DataFrame(data=None, columns=columns, index=df.index)    
        i = 1
        for c in columns:
            dfn[c] = df[k].shift(periods=i)
            i+=1
        df = pd.concat([df, dfn], axis=1, join_axes=[df.index])
        
    return df

# %%
NON_DER = ['wsid','elvt','lat', 'lon', 'yr', 'mo', 'da', 'hr']

dfr = df_derived_by_shift(dfm,24,NON_DER)

# %%
dfr.head(4)

var = []
cld = list(dfr.columns)
for x in cld:
    if len(x.split('_')) >= 2:
        var.append((x.split('_')[0], x.split('_')[1]))

# %%
cols = {}
for v,i in var:
    x = '{}_{}'.format(v, i)
    if int(i) not in cols:
        cols[int(i)] = [x]
    else:
        cols[int(i)].append(x)
#print cols

# %%
xxx = dfr.copy()

# %%
# Inicializando
xxx['prcp_acum_24'] = 99.99
xxx['prcp_plus_12'] = 99.99

# %%
for w in ws:
    
    size = xxx.loc[xxx['wsid'].isin([w])].iloc[:]['prcp'].count()
    
    pos_prcp = xxx.columns.get_loc('prcp')
    
    pos_acum_6 = xxx.columns.get_loc('prcp_acum_24')
    pos_plus_1 = xxx.columns.get_loc('prcp_plus_12')
    
    j=11
    
    for i in range(0,size):
        idx = xxx.loc[xxx['wsid'].isin([w])].index
        xxx.loc[xxx.loc[idx,'prcp_acum_24'].index[i],'prcp_acum_24'] = xxx.loc[xxx['wsid'].isin([w])].iloc[i:i+24,pos_prcp].sum()
        if i+12 < size:
            xxx.loc[xxx.loc[idx,'prcp_plus_12'].index[i],'prcp_plus_12'] = xxx.loc[xxx['wsid'].isin([w])].iloc[i:i+12,pos_prcp].sum()
        else:
            xxx.loc[xxx.loc[idx,'prcp_plus_12'].index[i],'prcp_plus_12']  = xxx.loc[xxx['wsid'].isin([w])].iloc[i:i+j,pos_prcp].sum()
            j-=1

# %%
dfr = xxx

# %%
dfr.head(12)
# Out:
#         wsid   elvt        lat        lon                 mdct  prcp    stp  \
# 816792   329  854.0 -19.883945 -43.969397  2006-12-01 00:00:00   0.0  915.4
# 816793   329  854.0 -19.883945 -43.969397  2006-12-01 01:00:00   0.0  916.0
# 816794   329  854.0 -19.883945 -43.969397  2006-12-01 02:00:00   0.4  916.0
# 816795   329  854.0 -19.883945 -43.969397  2006-12-01 03:00:00   1.8  915.1
# 816796   329  854.0 -19.883945 -43.969397  2006-12-01 04:00:00  12.4  914.4
# 816797   329  854.0 -19.883945 -43.969397  2006-12-01 05:00:00   0.6  913.8
# 816798   329  854.0 -19.883945 -43.969397  2006-12-01 06:00:00   0.0  913.5
# 816799   329  854.0 -19.883945 -43.969397  2006-12-01 07:00:00   0.0  913.4
# 816800   329  854.0 -19.883945 -43.969397  2006-12-01 08:00:00   0.0  914.2
# 816801   329  854.0 -19.883945 -43.969397  2006-12-01 09:00:00   0.0  915.0
# 816802   329  854.0 -19.883945 -43.969397  2006-12-01 10:00:00   0.0  915.7
# 816803   329  854.0 -19.883945 -43.969397  2006-12-01 11:00:00   0.0  916.2
#
#          smax   smin  temp      ...       dmax_17  dmax_18  dmax_19  dmax_20  \
# 816792  915.4  914.0  20.7      ...           NaN      NaN      NaN      NaN
# 816793  916.0  915.4  20.9      ...           NaN      NaN      NaN      NaN
# 816794  916.2  916.0  20.6      ...           NaN      NaN      NaN      NaN
# 816795  916.0  915.1  20.7      ...           NaN      NaN      NaN      NaN
# 816796  915.2  914.4  20.4      ...           NaN      NaN      NaN      NaN
# 816797  914.4  913.8  20.8      ...           NaN      NaN      NaN      NaN
# 816798  913.8  913.4  20.8      ...           NaN      NaN      NaN      NaN
# 816799  913.6  913.4  20.2      ...           NaN      NaN      NaN      NaN
# 816800  914.2  913.4  20.1      ...           NaN      NaN      NaN      NaN
# 816801  915.0  914.2  20.7      ...           NaN      NaN      NaN      NaN
# 816802  915.7  915.0  21.3      ...           NaN      NaN      NaN      NaN
# 816803  916.3  915.7  21.9      ...           NaN      NaN      NaN      NaN
#
#         dmax_21  dmax_22  dmax_23  dmax_24  prcp_acum_24  prcp_plus_12
# 816792      NaN      NaN      NaN      NaN          15.8          15.2
# 816793      NaN      NaN      NaN      NaN          15.8          15.2
# 816794      NaN      NaN      NaN      NaN          16.2          15.4
# 816795      NaN      NaN      NaN      NaN          16.8          15.0
# 816796      NaN      NaN      NaN      NaN          15.2          13.6
# 816797      NaN      NaN      NaN      NaN           2.8           1.2
# 816798      NaN      NaN      NaN      NaN           2.2           0.6
# 816799      NaN      NaN      NaN      NaN           2.2           0.6
# 816800      NaN      NaN      NaN      NaN           2.2           0.6
# 816801      NaN      NaN      NaN      NaN           2.6           0.6
# 816802      NaN      NaN      NaN      NaN           2.6           0.6
# 816803      NaN      NaN      NaN      NaN           2.6           0.6
#
# [12 rows x 356 columns]

# %%
dfr.columns
# Out:
# Index(['wsid', 'elvt', 'lat', 'lon', 'mdct', 'prcp', 'stp', 'smax', 'smin',
#        'temp',
#        ...
#        'dmax_17', 'dmax_18', 'dmax_19', 'dmax_20', 'dmax_21', 'dmax_22',
#        'dmax_23', 'dmax_24', 'prcp_acum_24', 'prcp_plus_12'],
#       dtype='object', length=356)

# %%
dfm = dfr

# %%
list(dfm.columns)
# Out:
# ['wsid',
#  'elvt',
#  'lat',
#  'lon',
#  'mdct',
#  'prcp',
#  'stp',
#  'smax',
#  'smin',
#  'temp',
#  'tmax',
#  'tmin',
#  'dewp',
#  'dmax',
#  'dmin',
#  'hmdy',
#  'hmax',
#  'hmin',
#  'tmin_1',
#  'tmin_2',
#  'tmin_3',
#  'tmin_4',
#  'tmin_5',
#  'tmin_6',
#  'tmin_7',
#  'tmin_8',
#  'tmin_9',
#  'tmin_10',
#  'tmin_11',
#  'tmin_12',
#  'tmin_13',
#  'tmin_14',
#  'tmin_15',
#  'tmin_16',
#  'tmin_17',
#  'tmin_18',
#  'tmin_19',
#  'tmin_20',
#  'tmin_21',
#  'tmin_22',
#  'tmin_23',
#  'tmin_24',
#  'temp_1',
#  'temp_2',
#  'temp_3',
#  'temp_4',
#  'temp_5',
#  'temp_6',
#  'temp_7',
#  'temp_8',
#  'temp_9',
#  'temp_10',
#  'temp_11',
#  'temp_12',
#  'temp_13',
#  'temp_14',
#  'temp_15',
#  'temp_16',
#  'temp_17',
#  'temp_18',
#  'temp_19',
#  'temp_20',
#  'temp_21',
#  'temp_22',
#  'temp_23',
#  'temp_24',
#  'stp_1',
#  'stp_2',
#  'stp_3',
#  'stp_4',
#  'stp_5',
#  'stp_6',
#  'stp_7',
#  'stp_8',
#  'stp_9',
#  'stp_10',
#  'stp_11',
#  'stp_12',
#  'stp_13',
#  'stp_14',
#  'stp_15',
#  'stp_16',
#  'stp_17',
#  'stp_18',
#  'stp_19',
#  'stp_20',
#  'stp_21',
#  'stp_22',
#  'stp_23',
#  'stp_24',
#  'mdct_1',
#  'mdct_2',
#  'mdct_3',
#  'mdct_4',
#  'mdct_5',
#  'mdct_6',
#  'mdct_7',
#  'mdct_8',
#  'mdct_9',
#  'mdct_10',
#  'mdct_11',
#  'mdct_12',
#  'mdct_13',
#  'mdct_14',
#  'mdct_15',
#  'mdct_16',
#  'mdct_17',
#  'mdct_18',
#  'mdct_19',
#  'mdct_20',
#  'mdct_21',
#  'mdct_22',
#  'mdct_23',
#  'mdct_24',
#  'dewp_1',
#  'dewp_2',
#  'dewp_3',
#  'dewp_4',
#  'dewp_5',
#  'dewp_6',
#  'dewp_7',
#  'dewp_8',
#  'dewp_9',
#  'dewp_10',
#  'dewp_11',
#  'dewp_12',
#  'dewp_13',
#  'dewp_14',
#  'dewp_15',
#  'dewp_16',
#  'dewp_17',
#  'dewp_18',
#  'dewp_19',
#  'dewp_20',
#  'dewp_21',
#  'dewp_22',
#  'dewp_23',
#  'dewp_24',
#  'hmin_1',
#  'hmin_2',
#  'hmin_3',
#  'hmin_4',
#  'hmin_5',
#  'hmin_6',
#  'hmin_7',
#  'hmin_8',
#  'hmin_9',
#  'hmin_10',
#  'hmin_11',
#  'hmin_12',
#  'hmin_13',
#  'hmin_14',
#  'hmin_15',
#  'hmin_16',
#  'hmin_17',
#  'hmin_18',
#  'hmin_19',
#  'hmin_20',
#  'hmin_21',
#  'hmin_22',
#  'hmin_23',
#  'hmin_24',
#  'dmin_1',
#  'dmin_2',
#  'dmin_3',
#  'dmin_4',
#  'dmin_5',
#  'dmin_6',
#  'dmin_7',
#  'dmin_8',
#  'dmin_9',
#  'dmin_10',
#  'dmin_11',
#  'dmin_12',
#  'dmin_13',
#  'dmin_14',
#  'dmin_15',
#  'dmin_16',
#  'dmin_17',
#  'dmin_18',
#  'dmin_19',
#  'dmin_20',
#  'dmin_21',
#  'dmin_22',
#  'dmin_23',
#  'dmin_24',
#  'prcp_1',
#  'prcp_2',
#  'prcp_3',
#  'prcp_4',
#  'prcp_5',
#  'prcp_6',
#  'prcp_7',
#  'prcp_8',
#  'prcp_9',
#  'prcp_10',
#  'prcp_11',
#  'prcp_12',
#  'prcp_13',
#  'prcp_14',
#  'prcp_15',
#  'prcp_16',
#  'prcp_17',
#  'prcp_18',
#  'prcp_19',
#  'prcp_20',
#  'prcp_21',
#  'prcp_22',
#  'prcp_23',
#  'prcp_24',
#  'tmax_1',
#  'tmax_2',
#  'tmax_3',
#  'tmax_4',
#  'tmax_5',
#  'tmax_6',
#  'tmax_7',
#  'tmax_8',
#  'tmax_9',
#  'tmax_10',
#  'tmax_11',
#  'tmax_12',
#  'tmax_13',
#  'tmax_14',
#  'tmax_15',
#  'tmax_16',
#  'tmax_17',
#  'tmax_18',
#  'tmax_19',
#  'tmax_20',
#  'tmax_21',
#  'tmax_22',
#  'tmax_23',
#  'tmax_24',
#  'smax_1',
#  'smax_2',
#  'smax_3',
#  'smax_4',
#  'smax_5',
#  'smax_6',
#  'smax_7',
#  'smax_8',
#  'smax_9',
#  'smax_10',
#  'smax_11',
#  'smax_12',
#  'smax_13',
#  'smax_14',
#  'smax_15',
#  'smax_16',
#  'smax_17',
#  'smax_18',
#  'smax_19',
#  'smax_20',
#  'smax_21',
#  'smax_22',
#  'smax_23',
#  'smax_24',
#  'hmdy_1',
#  'hmdy_2',
#  'hmdy_3',
#  'hmdy_4',
#  'hmdy_5',
#  'hmdy_6',
#  'hmdy_7',
#  'hmdy_8',
#  'hmdy_9',
#  'hmdy_10',
#  'hmdy_11',
#  'hmdy_12',
#  'hmdy_13',
#  'hmdy_14',
#  'hmdy_15',
#  'hmdy_16',
#  'hmdy_17',
#  'hmdy_18',
#  'hmdy_19',
#  'hmdy_20',
#  'hmdy_21',
#  'hmdy_22',
#  'hmdy_23',
#  'hmdy_24',
#  'hmax_1',
#  'hmax_2',
#  'hmax_3',
#  'hmax_4',
#  'hmax_5',
#  'hmax_6',
#  'hmax_7',
#  'hmax_8',
#  'hmax_9',
#  'hmax_10',
#  'hmax_11',
#  'hmax_12',
#  'hmax_13',
#  'hmax_14',
#  'hmax_15',
#  'hmax_16',
#  'hmax_17',
#  'hmax_18',
#  'hmax_19',
#  'hmax_20',
#  'hmax_21',
#  'hmax_22',
#  'hmax_23',
#  'hmax_24',
#  'smin_1',
#  'smin_2',
#  'smin_3',
#  'smin_4',
#  'smin_5',
#  'smin_6',
#  'smin_7',
#  'smin_8',
#  'smin_9',
#  'smin_10',
#  'smin_11',
#  'smin_12',
#  'smin_13',
#  'smin_14',
#  'smin_15',
#  'smin_16',
#  'smin_17',
#  'smin_18',
#  'smin_19',
#  'smin_20',
#  'smin_21',
#  'smin_22',
#  'smin_23',
#  'smin_24',
#  'dmax_1',
#  'dmax_2',
#  'dmax_3',
#  'dmax_4',
#  'dmax_5',
#  'dmax_6',
#  'dmax_7',
#  'dmax_8',
#  'dmax_9',
#  'dmax_10',
#  'dmax_11',
#  'dmax_12',
#  'dmax_13',
#  'dmax_14',
#  'dmax_15',
#  'dmax_16',
#  'dmax_17',
#  'dmax_18',
#  'dmax_19',
#  'dmax_20',
#  'dmax_21',
#  'dmax_22',
#  'dmax_23',
#  'dmax_24',
#  'prcp_acum_24',
#  'prcp_plus_12']

# %%
len(dfm)
# Out:
# 29112

# %% [markdown]
# <h3>Preparando a base</h3>

# %% [markdown]
# <p>Removendo registros que não pode ser nulos e prejudicariam o treinamento</p>

# %%
cols = list(df.columns)
for v in ['wdsp','wdct','gust']:
    cols.remove(v)

# %%
COLS_BE_NULL = ['prcp'] + DES + ['temp']
for v in COLS_BE_NULL:
    if v in cols:
        cols.remove(v)
cols
# Out:
# ['stp',
#  'smax',
#  'smin',
#  'tmax',
#  'tmin',
#  'dewp',
#  'dmax',
#  'dmin',
#  'hmdy',
#  'hmax',
#  'hmin']

# %%
dfm[cols] = dfm[cols].replace({0.0:np.nan})

# %%
print (len(dfm))
dfm  = dfm.dropna()
print (len(dfm))
# Out:
# 29112
# 27721

# %%
dfm = dfm.reset_index(drop=True)

# %%
dfm.head(5)
# Out:
#    wsid   elvt        lat        lon                 mdct  prcp    stp   smax  \
# 0   329  854.0 -19.883945 -43.969397  2006-12-02 00:00:00   0.0  918.2  918.2
# 1   329  854.0 -19.883945 -43.969397  2006-12-02 01:00:00   0.4  918.7  918.7
# 2   329  854.0 -19.883945 -43.969397  2006-12-02 02:00:00   1.0  918.7  918.8
# 3   329  854.0 -19.883945 -43.969397  2006-12-02 03:00:00   0.2  918.1  918.7
# 4   329  854.0 -19.883945 -43.969397  2006-12-02 04:00:00   0.0  917.3  918.1
#
#     smin  temp      ...       dmax_17  dmax_18  dmax_19  dmax_20  dmax_21  \
# 0  917.5  18.8      ...          20.2     20.1     20.2     20.4     20.6
# 1  918.2  18.6      ...          19.9     20.2     20.1     20.2     20.4
# 2  918.7  18.4      ...          19.9     19.9     20.2     20.1     20.2
# 3  918.1  18.6      ...          20.6     19.9     19.9     20.2     20.1
# 4  917.3  18.7      ...          21.2     20.6     19.9     19.9     20.2
#
#    dmax_22  dmax_23  dmax_24  prcp_acum_24  prcp_plus_12
# 0     20.5     20.7     20.4           2.0           2.0
# 1     20.6     20.5     20.7           2.0           2.0
# 2     20.4     20.6     20.5           1.6           1.6
# 3     20.2     20.4     20.6           0.6           0.6
# 4     20.1     20.2     20.4           0.4           0.4
#
# [5 rows x 356 columns]

# %%
dfm = dfm.drop('wsid',1)
dfm = dfm.drop('mdct',1)

# %%
list(dfm.columns)
# Out:
# ['elvt',
#  'lat',
#  'lon',
#  'prcp',
#  'stp',
#  'smax',
#  'smin',
#  'temp',
#  'tmax',
#  'tmin',
#  'dewp',
#  'dmax',
#  'dmin',
#  'hmdy',
#  'hmax',
#  'hmin',
#  'tmin_1',
#  'tmin_2',
#  'tmin_3',
#  'tmin_4',
#  'tmin_5',
#  'tmin_6',
#  'tmin_7',
#  'tmin_8',
#  'tmin_9',
#  'tmin_10',
#  'tmin_11',
#  'tmin_12',
#  'tmin_13',
#  'tmin_14',
#  'tmin_15',
#  'tmin_16',
#  'tmin_17',
#  'tmin_18',
#  'tmin_19',
#  'tmin_20',
#  'tmin_21',
#  'tmin_22',
#  'tmin_23',
#  'tmin_24',
#  'temp_1',
#  'temp_2',
#  'temp_3',
#  'temp_4',
#  'temp_5',
#  'temp_6',
#  'temp_7',
#  'temp_8',
#  'temp_9',
#  'temp_10',
#  'temp_11',
#  'temp_12',
#  'temp_13',
#  'temp_14',
#  'temp_15',
#  'temp_16',
#  'temp_17',
#  'temp_18',
#  'temp_19',
#  'temp_20',
#  'temp_21',
#  'temp_22',
#  'temp_23',
#  'temp_24',
#  'stp_1',
#  'stp_2',
#  'stp_3',
#  'stp_4',
#  'stp_5',
#  'stp_6',
#  'stp_7',
#  'stp_8',
#  'stp_9',
#  'stp_10',
#  'stp_11',
#  'stp_12',
#  'stp_13',
#  'stp_14',
#  'stp_15',
#  'stp_16',
#  'stp_17',
#  'stp_18',
#  'stp_19',
#  'stp_20',
#  'stp_21',
#  'stp_22',
#  'stp_23',
#  'stp_24',
#  'mdct_1',
#  'mdct_2',
#  'mdct_3',
#  'mdct_4',
#  'mdct_5',
#  'mdct_6',
#  'mdct_7',
#  'mdct_8',
#  'mdct_9',
#  'mdct_10',
#  'mdct_11',
#  'mdct_12',
#  'mdct_13',
#  'mdct_14',
#  'mdct_15',
#  'mdct_16',
#  'mdct_17',
#  'mdct_18',
#  'mdct_19',
#  'mdct_20',
#  'mdct_21',
#  'mdct_22',
#  'mdct_23',
#  'mdct_24',
#  'dewp_1',
#  'dewp_2',
#  'dewp_3',
#  'dewp_4',
#  'dewp_5',
#  'dewp_6',
#  'dewp_7',
#  'dewp_8',
#  'dewp_9',
#  'dewp_10',
#  'dewp_11',
#  'dewp_12',
#  'dewp_13',
#  'dewp_14',
#  'dewp_15',
#  'dewp_16',
#  'dewp_17',
#  'dewp_18',
#  'dewp_19',
#  'dewp_20',
#  'dewp_21',
#  'dewp_22',
#  'dewp_23',
#  'dewp_24',
#  'hmin_1',
#  'hmin_2',
#  'hmin_3',
#  'hmin_4',
#  'hmin_5',
#  'hmin_6',
#  'hmin_7',
#  'hmin_8',
#  'hmin_9',
#  'hmin_10',
#  'hmin_11',
#  'hmin_12',
#  'hmin_13',
#  'hmin_14',
#  'hmin_15',
#  'hmin_16',
#  'hmin_17',
#  'hmin_18',
#  'hmin_19',
#  'hmin_20',
#  'hmin_21',
#  'hmin_22',
#  'hmin_23',
#  'hmin_24',
#  'dmin_1',
#  'dmin_2',
#  'dmin_3',
#  'dmin_4',
#  'dmin_5',
#  'dmin_6',
#  'dmin_7',
#  'dmin_8',
#  'dmin_9',
#  'dmin_10',
#  'dmin_11',
#  'dmin_12',
#  'dmin_13',
#  'dmin_14',
#  'dmin_15',
#  'dmin_16',
#  'dmin_17',
#  'dmin_18',
#  'dmin_19',
#  'dmin_20',
#  'dmin_21',
#  'dmin_22',
#  'dmin_23',
#  'dmin_24',
#  'prcp_1',
#  'prcp_2',
#  'prcp_3',
#  'prcp_4',
#  'prcp_5',
#  'prcp_6',
#  'prcp_7',
#  'prcp_8',
#  'prcp_9',
#  'prcp_10',
#  'prcp_11',
#  'prcp_12',
#  'prcp_13',
#  'prcp_14',
#  'prcp_15',
#  'prcp_16',
#  'prcp_17',
#  'prcp_18',
#  'prcp_19',
#  'prcp_20',
#  'prcp_21',
#  'prcp_22',
#  'prcp_23',
#  'prcp_24',
#  'tmax_1',
#  'tmax_2',
#  'tmax_3',
#  'tmax_4',
#  'tmax_5',
#  'tmax_6',
#  'tmax_7',
#  'tmax_8',
#  'tmax_9',
#  'tmax_10',
#  'tmax_11',
#  'tmax_12',
#  'tmax_13',
#  'tmax_14',
#  'tmax_15',
#  'tmax_16',
#  'tmax_17',
#  'tmax_18',
#  'tmax_19',
#  'tmax_20',
#  'tmax_21',
#  'tmax_22',
#  'tmax_23',
#  'tmax_24',
#  'smax_1',
#  'smax_2',
#  'smax_3',
#  'smax_4',
#  'smax_5',
#  'smax_6',
#  'smax_7',
#  'smax_8',
#  'smax_9',
#  'smax_10',
#  'smax_11',
#  'smax_12',
#  'smax_13',
#  'smax_14',
#  'smax_15',
#  'smax_16',
#  'smax_17',
#  'smax_18',
#  'smax_19',
#  'smax_20',
#  'smax_21',
#  'smax_22',
#  'smax_23',
#  'smax_24',
#  'hmdy_1',
#  'hmdy_2',
#  'hmdy_3',
#  'hmdy_4',
#  'hmdy_5',
#  'hmdy_6',
#  'hmdy_7',
#  'hmdy_8',
#  'hmdy_9',
#  'hmdy_10',
#  'hmdy_11',
#  'hmdy_12',
#  'hmdy_13',
#  'hmdy_14',
#  'hmdy_15',
#  'hmdy_16',
#  'hmdy_17',
#  'hmdy_18',
#  'hmdy_19',
#  'hmdy_20',
#  'hmdy_21',
#  'hmdy_22',
#  'hmdy_23',
#  'hmdy_24',
#  'hmax_1',
#  'hmax_2',
#  'hmax_3',
#  'hmax_4',
#  'hmax_5',
#  'hmax_6',
#  'hmax_7',
#  'hmax_8',
#  'hmax_9',
#  'hmax_10',
#  'hmax_11',
#  'hmax_12',
#  'hmax_13',
#  'hmax_14',
#  'hmax_15',
#  'hmax_16',
#  'hmax_17',
#  'hmax_18',
#  'hmax_19',
#  'hmax_20',
#  'hmax_21',
#  'hmax_22',
#  'hmax_23',
#  'hmax_24',
#  'smin_1',
#  'smin_2',
#  'smin_3',
#  'smin_4',
#  'smin_5',
#  'smin_6',
#  'smin_7',
#  'smin_8',
#  'smin_9',
#  'smin_10',
#  'smin_11',
#  'smin_12',
#  'smin_13',
#  'smin_14',
#  'smin_15',
#  'smin_16',
#  'smin_17',
#  'smin_18',
#  'smin_19',
#  'smin_20',
#  'smin_21',
#  'smin_22',
#  'smin_23',
#  'smin_24',
#  'dmax_1',
#  'dmax_2',
#  'dmax_3',
#  'dmax_4',
#  'dmax_5',
#  'dmax_6',
#  'dmax_7',
#  'dmax_8',
#  'dmax_9',
#  'dmax_10',
#  'dmax_11',
#  'dmax_12',
#  'dmax_13',
#  'dmax_14',
#  'dmax_15',
#  'dmax_16',
#  'dmax_17',
#  'dmax_18',
#  'dmax_19',
#  'dmax_20',
#  'dmax_21',
#  'dmax_22',
#  'dmax_23',
#  'dmax_24',
#  'prcp_acum_24',
#  'prcp_plus_12']

# %%
REMOVE = ['mdct']
for i in range(1,25):
    REMOVE.append('mdct_'+str(i))
print (REMOVE)
for v in REMOVE:
    if v in list(dfm.columns):
        dfm = dfm.drop(v,1)
# Out:
# ['mdct', 'mdct_1', 'mdct_2', 'mdct_3', 'mdct_4', 'mdct_5', 'mdct_6', 'mdct_7', 'mdct_8', 'mdct_9', 'mdct_10', 'mdct_11', 'mdct_12', 'mdct_13', 'mdct_14', 'mdct_15', 'mdct_16', 'mdct_17', 'mdct_18', 'mdct_19', 'mdct_20', 'mdct_21', 'mdct_22', 'mdct_23', 'mdct_24']

# %%
list(dfm.columns)
# Out:
# ['elvt',
#  'lat',
#  'lon',
#  'prcp',
#  'stp',
#  'smax',
#  'smin',
#  'temp',
#  'tmax',
#  'tmin',
#  'dewp',
#  'dmax',
#  'dmin',
#  'hmdy',
#  'hmax',
#  'hmin',
#  'tmin_1',
#  'tmin_2',
#  'tmin_3',
#  'tmin_4',
#  'tmin_5',
#  'tmin_6',
#  'tmin_7',
#  'tmin_8',
#  'tmin_9',
#  'tmin_10',
#  'tmin_11',
#  'tmin_12',
#  'tmin_13',
#  'tmin_14',
#  'tmin_15',
#  'tmin_16',
#  'tmin_17',
#  'tmin_18',
#  'tmin_19',
#  'tmin_20',
#  'tmin_21',
#  'tmin_22',
#  'tmin_23',
#  'tmin_24',
#  'temp_1',
#  'temp_2',
#  'temp_3',
#  'temp_4',
#  'temp_5',
#  'temp_6',
#  'temp_7',
#  'temp_8',
#  'temp_9',
#  'temp_10',
#  'temp_11',
#  'temp_12',
#  'temp_13',
#  'temp_14',
#  'temp_15',
#  'temp_16',
#  'temp_17',
#  'temp_18',
#  'temp_19',
#  'temp_20',
#  'temp_21',
#  'temp_22',
#  'temp_23',
#  'temp_24',
#  'stp_1',
#  'stp_2',
#  'stp_3',
#  'stp_4',
#  'stp_5',
#  'stp_6',
#  'stp_7',
#  'stp_8',
#  'stp_9',
#  'stp_10',
#  'stp_11',
#  'stp_12',
#  'stp_13',
#  'stp_14',
#  'stp_15',
#  'stp_16',
#  'stp_17',
#  'stp_18',
#  'stp_19',
#  'stp_20',
#  'stp_21',
#  'stp_22',
#  'stp_23',
#  'stp_24',
#  'dewp_1',
#  'dewp_2',
#  'dewp_3',
#  'dewp_4',
#  'dewp_5',
#  'dewp_6',
#  'dewp_7',
#  'dewp_8',
#  'dewp_9',
#  'dewp_10',
#  'dewp_11',
#  'dewp_12',
#  'dewp_13',
#  'dewp_14',
#  'dewp_15',
#  'dewp_16',
#  'dewp_17',
#  'dewp_18',
#  'dewp_19',
#  'dewp_20',
#  'dewp_21',
#  'dewp_22',
#  'dewp_23',
#  'dewp_24',
#  'hmin_1',
#  'hmin_2',
#  'hmin_3',
#  'hmin_4',
#  'hmin_5',
#  'hmin_6',
#  'hmin_7',
#  'hmin_8',
#  'hmin_9',
#  'hmin_10',
#  'hmin_11',
#  'hmin_12',
#  'hmin_13',
#  'hmin_14',
#  'hmin_15',
#  'hmin_16',
#  'hmin_17',
#  'hmin_18',
#  'hmin_19',
#  'hmin_20',
#  'hmin_21',
#  'hmin_22',
#  'hmin_23',
#  'hmin_24',
#  'dmin_1',
#  'dmin_2',
#  'dmin_3',
#  'dmin_4',
#  'dmin_5',
#  'dmin_6',
#  'dmin_7',
#  'dmin_8',
#  'dmin_9',
#  'dmin_10',
#  'dmin_11',
#  'dmin_12',
#  'dmin_13',
#  'dmin_14',
#  'dmin_15',
#  'dmin_16',
#  'dmin_17',
#  'dmin_18',
#  'dmin_19',
#  'dmin_20',
#  'dmin_21',
#  'dmin_22',
#  'dmin_23',
#  'dmin_24',
#  'prcp_1',
#  'prcp_2',
#  'prcp_3',
#  'prcp_4',
#  'prcp_5',
#  'prcp_6',
#  'prcp_7',
#  'prcp_8',
#  'prcp_9',
#  'prcp_10',
#  'prcp_11',
#  'prcp_12',
#  'prcp_13',
#  'prcp_14',
#  'prcp_15',
#  'prcp_16',
#  'prcp_17',
#  'prcp_18',
#  'prcp_19',
#  'prcp_20',
#  'prcp_21',
#  'prcp_22',
#  'prcp_23',
#  'prcp_24',
#  'tmax_1',
#  'tmax_2',
#  'tmax_3',
#  'tmax_4',
#  'tmax_5',
#  'tmax_6',
#  'tmax_7',
#  'tmax_8',
#  'tmax_9',
#  'tmax_10',
#  'tmax_11',
#  'tmax_12',
#  'tmax_13',
#  'tmax_14',
#  'tmax_15',
#  'tmax_16',
#  'tmax_17',
#  'tmax_18',
#  'tmax_19',
#  'tmax_20',
#  'tmax_21',
#  'tmax_22',
#  'tmax_23',
#  'tmax_24',
#  'smax_1',
#  'smax_2',
#  'smax_3',
#  'smax_4',
#  'smax_5',
#  'smax_6',
#  'smax_7',
#  'smax_8',
#  'smax_9',
#  'smax_10',
#  'smax_11',
#  'smax_12',
#  'smax_13',
#  'smax_14',
#  'smax_15',
#  'smax_16',
#  'smax_17',
#  'smax_18',
#  'smax_19',
#  'smax_20',
#  'smax_21',
#  'smax_22',
#  'smax_23',
#  'smax_24',
#  'hmdy_1',
#  'hmdy_2',
#  'hmdy_3',
#  'hmdy_4',
#  'hmdy_5',
#  'hmdy_6',
#  'hmdy_7',
#  'hmdy_8',
#  'hmdy_9',
#  'hmdy_10',
#  'hmdy_11',
#  'hmdy_12',
#  'hmdy_13',
#  'hmdy_14',
#  'hmdy_15',
#  'hmdy_16',
#  'hmdy_17',
#  'hmdy_18',
#  'hmdy_19',
#  'hmdy_20',
#  'hmdy_21',
#  'hmdy_22',
#  'hmdy_23',
#  'hmdy_24',
#  'hmax_1',
#  'hmax_2',
#  'hmax_3',
#  'hmax_4',
#  'hmax_5',
#  'hmax_6',
#  'hmax_7',
#  'hmax_8',
#  'hmax_9',
#  'hmax_10',
#  'hmax_11',
#  'hmax_12',
#  'hmax_13',
#  'hmax_14',
#  'hmax_15',
#  'hmax_16',
#  'hmax_17',
#  'hmax_18',
#  'hmax_19',
#  'hmax_20',
#  'hmax_21',
#  'hmax_22',
#  'hmax_23',
#  'hmax_24',
#  'smin_1',
#  'smin_2',
#  'smin_3',
#  'smin_4',
#  'smin_5',
#  'smin_6',
#  'smin_7',
#  'smin_8',
#  'smin_9',
#  'smin_10',
#  'smin_11',
#  'smin_12',
#  'smin_13',
#  'smin_14',
#  'smin_15',
#  'smin_16',
#  'smin_17',
#  'smin_18',
#  'smin_19',
#  'smin_20',
#  'smin_21',
#  'smin_22',
#  'smin_23',
#  'smin_24',
#  'dmax_1',
#  'dmax_2',
#  'dmax_3',
#  'dmax_4',
#  'dmax_5',
#  'dmax_6',
#  'dmax_7',
#  'dmax_8',
#  'dmax_9',
#  'dmax_10',
#  'dmax_11',
#  'dmax_12',
#  'dmax_13',
#  'dmax_14',
#  'dmax_15',
#  'dmax_16',
#  'dmax_17',
#  'dmax_18',
#  'dmax_19',
#  'dmax_20',
#  'dmax_21',
#  'dmax_22',
#  'dmax_23',
#  'dmax_24',
#  'prcp_acum_24',
#  'prcp_plus_12']

# %%
#como esta rede é especifica para a BH, vamos remover elvt, lat, lon
REMOVE = ['elvt','lat', 'lon']
for v in REMOVE:
    dfm = dfm.drop(v,1)

# %%
#dfm = dfm.drop('wsid',1)
#dfm

# %%
#dfm.loc[28807,'prcp_plus_1'] = 0.0
#x = dfm[dfm['prcp_plus_1']==99.99]
#x

# %%
#dfm.to_csv('../data/derivaded_3.csv')

# %%
dfm = pd.read_csv('../data/derivaded_3.csv',index_col=0)
print (len(dfm))
dfm.head(24)
# Out:
# 27721
#     prcp    stp   smax   smin  temp  tmax  tmin  dewp  dmax  dmin  \
# 0    0.0  918.2  918.2  917.5  18.8  17.1  20.2  17.1  18.8  16.2
# 1    0.4  918.7  918.7  918.2  18.6  17.2  18.9  17.2  18.6  17.1
# 2    1.0  918.7  918.8  918.7  18.4  17.3  18.6  17.4  18.3  17.2
# 3    0.2  918.1  918.7  918.1  18.6  17.3  18.8  17.4  18.4  17.2
# 4    0.0  917.3  918.1  917.3  18.7  17.1  18.8  17.3  18.5  17.0
# 5    0.0  916.6  917.3  916.6  18.6  16.8  18.8  17.1  18.5  16.8
# 6    0.0  916.4  916.6  916.3  18.3  16.5  18.8  16.8  18.3  16.4
# 7    0.0  916.5  916.5  916.4  18.3  16.3  18.4  16.6  18.2  16.3
# 8    0.4  917.2  917.2  916.5  18.0  16.4  18.5  16.4  17.9  16.2
# 9    0.0  918.0  918.0  917.2  18.4  15.9  18.5  16.4  17.9  15.8
# 10   0.0  918.5  918.5  918.0  18.7  15.9  18.7  16.2  18.3  15.7
# 11   0.0  919.2  919.2  918.4  19.6  16.4  19.9  16.7  18.7  15.9
# 12   0.0  919.8  919.8  919.2  20.6  16.9  20.6  17.0  19.6  16.1
# 13   0.0  919.9  919.9  919.8  21.1  16.3  21.3  17.0  20.6  16.1
# 14   0.0  919.6  919.9  919.6  22.1  17.1  22.1  17.1  21.0  15.9
# 15   0.0  919.1  919.7  919.1  22.9  16.8  22.9  17.8  21.8  16.2
# 16   0.0  918.3  919.2  918.3  24.4  16.6  24.7  17.9  22.7  16.2
# 17   0.0  917.5  918.3  917.5  25.2  16.0  25.9  17.7  24.4  15.7
# 18   0.0  916.9  917.5  916.9  25.2  16.8  26.0  17.4  24.7  15.8
# 19   0.0  916.7  916.9  916.7  24.6  16.9  25.3  17.5  24.6  16.2
# 20   0.0  916.7  916.8  916.6  23.9  17.0  24.8  17.6  23.9  16.7
# 21   0.0  916.9  916.9  916.5  23.4  16.8  23.9  17.1  23.4  16.6
# 22   0.0  917.4  917.4  916.9  22.5  17.4  23.4  17.4  22.4  16.7
# 23   0.0  917.9  917.9  917.4  21.6  17.0  22.5  17.4  21.6  17.0
#
#         ...       dmax_17  dmax_18  dmax_19  dmax_20  dmax_21  dmax_22  \
# 0       ...          20.2     20.1     20.2     20.4     20.6     20.5
# 1       ...          19.9     20.2     20.1     20.2     20.4     20.6
# 2       ...          19.9     19.9     20.2     20.1     20.2     20.4
# 3       ...          20.6     19.9     19.9     20.2     20.1     20.2
# 4       ...          21.2     20.6     19.9     19.9     20.2     20.1
# 5       ...          21.9     21.2     20.6     19.9     19.9     20.2
# 6       ...          22.2     21.9     21.2     20.6     19.9     19.9
# 7       ...          21.8     22.2     21.9     21.2     20.6     19.9
# 8       ...          22.1     21.8     22.2     21.9     21.2     20.6
# 9       ...          22.3     22.1     21.8     22.2     21.9     21.2
# 10      ...          22.7     22.3     22.1     21.8     22.2     21.9
# 11      ...          22.3     22.7     22.3     22.1     21.8     22.2
# 12      ...          21.8     22.3     22.7     22.3     22.1     21.8
# 13      ...          21.8     21.8     22.3     22.7     22.3     22.1
# 14      ...          21.5     21.8     21.8     22.3     22.7     22.3
# 15      ...          21.0     21.5     21.8     21.8     22.3     22.7
# 16      ...          20.2     21.0     21.5     21.8     21.8     22.3
# 17      ...          18.8     20.2     21.0     21.5     21.8     21.8
# 18      ...          18.6     18.8     20.2     21.0     21.5     21.8
# 19      ...          18.3     18.6     18.8     20.2     21.0     21.5
# 20      ...          18.4     18.3     18.6     18.8     20.2     21.0
# 21      ...          18.5     18.4     18.3     18.6     18.8     20.2
# 22      ...          18.5     18.5     18.4     18.3     18.6     18.8
# 23      ...          18.3     18.5     18.5     18.4     18.3     18.6
#
#     dmax_23  dmax_24  prcp_acum_24  prcp_plus_12
# 0      20.7     20.4           2.0           2.0
# 1      20.5     20.7           2.0           2.0
# 2      20.6     20.5           1.6           1.6
# 3      20.4     20.6           0.6           0.6
# 4      20.2     20.4           0.4           0.4
# 5      20.1     20.2           0.4           0.4
# 6      20.2     20.1           0.4           0.4
# 7      19.9     20.2           0.4           0.4
# 8      19.9     19.9           0.4           0.4
# 9      20.6     19.9           0.0           0.0
# 10     21.2     20.6           0.0           0.0
# 11     21.9     21.2           0.0           0.0
# 12     22.2     21.9           0.0           0.0
# 13     21.8     22.2           0.0           0.0
# 14     22.1     21.8           0.0           0.0
# 15     22.3     22.1           0.0           0.0
# 16     22.7     22.3           0.0           0.0
# 17     22.3     22.7           0.0           0.0
# 18     21.8     22.3           0.0           0.0
# 19     21.8     21.8           0.0           0.0
# 20     21.5     21.8           0.0           0.0
# 21     21.0     21.5           0.0           0.0
# 22     20.2     21.0           0.0           0.0
# 23     18.8     20.2           0.0           0.0
#
# [24 rows x 327 columns]

# %% [markdown]
# <h2>Mineiração dos dados</h2>

# %% [markdown]
# <h3>Rede neural</h3>

# %%
import tensorflow as tf  
from sklearn.metrics import explained_variance_score, mean_absolute_error,  median_absolute_error
from sklearn.model_selection import train_test_split

# %%
target = 'prcp_acum_24'

# %%
X = dfm[[col for col in dfm.columns]]
y = dfm[target]

# %% [markdown]
# <p>Separando o conjunto de treinamento e validação (metade dos 10% separados para validação)</p>

# %%
X_train, X_tmp, y_train, y_tmp = train_test_split(X, y, test_size=0.2, random_state=12) 
print (len(X_train))
print (len(X_tmp))
# Out:
# 22176
# 5545

# %% [markdown]
# <p>Separando o conjunto de testes</p>

# %%
X_test, X_val, y_test, y_val = train_test_split(X_tmp, y_tmp, test_size=0.5)

# %%
X_train.shape, X_test.shape, X_val.shape  
print("Training instances   {}, Training features   {}".format(X_train.shape[0], X_train.shape[1]))  
print("Validation instances {}, Validation features {}".format(X_val.shape[0], X_val.shape[1]))  
print("Testing instances    {}, Testing features    {}".format(X_test.shape[0], X_test.shape[1]))
# Out:
# Training instances   22176, Training features   327
# Validation instances 2773, Validation features 327
# Testing instances    2772, Testing features    327

# %%
# Zarate instructions
st_units = (X_train.shape[1] * 2) + 1
sd_units = X_train.shape[1] 
#activation_fn = tf.sigmoid
batch_size = 1000
up = int(len(X_train)/batch_size)

# %%
Z = X.copy()
Z.pop(target)
Z.pop('prcp_plus_12')
feature_cols = [tf.feature_column.numeric_column(col) for col in Z.columns]

# %%
feature_cols
# Out:
# [_NumericColumn(key='prcp', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmin_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='temp_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='stp_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dewp_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmin_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmin_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='prcp_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='tmax_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smax_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmdy_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='hmax_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='smin_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_4', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_5', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_6', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_7', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_8', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_9', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_10', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_11', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_12', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_13', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_14', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_15', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_16', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_17', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_18', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_19', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_20', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_21', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_22', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_23', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='dmax_24', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
regressor = tf.estimator.DNNRegressor(feature_columns=feature_cols
                                      ,hidden_units=[st_units,sd_units]
                                      #,activation_fn=activation_fn
                                      ,model_dir='/tmp/tf_model_14')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tf_model_14', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x10c69e320>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
def wx_input_fn(X, y=None, num_epochs=None, shuffle=True, batch_size=batch_size):      
    return tf.estimator.inputs.pandas_input_fn(x=X,
                                               y=y,
                                               num_epochs=num_epochs,
                                               shuffle=shuffle,
                                               batch_size=batch_size)

# %%
from imblearn.under_sampling import RandomUnderSampler
under = RandomUnderSampler(return_indices=True)

# %%
def balancear(_X, _y):
    
    def f(x):
        if x['prcp_acum_24'] <= 0.0: 
            return 0
        elif x['prcp_acum_24'] < 50:       
            return 1
        else:
            return 2        
        
    #Balancear considerando considerando: a) sem chuva b) chuva  c) chuva extrema  
    _X.loc[:,('rain')] = _X.apply(f,axis=1) 
    
    _X_resampled, _y_resampled, idx_resampled = under.fit_sample(_X, _X['rain'])
    
    _X = pd.DataFrame(_X_resampled, columns = _X.columns)
    _y = pd.DataFrame(_y_resampled, columns =['prcp_acum_24'])
    
    for c in ['prcp_plus_12','prcp_acum_24','rain']:
        _X = _X.drop(c,1)
    
    return _X,_y

# %%
#X_val = X_val.drop('prcp_plus_12',1)
#X_val = X_val.drop('prcp_acum_24',1)
#X_train =  X_train.drop('prcp_plus_12',1)
#X_train =  X_train.drop('prcp_acum_24',1)

# %%
def f(x):
    if x['prcp_acum_24'] <= 0.0: 
        return 0
    elif x['prcp_acum_24'] < 50:       
        return 1
    else:
        return 2

# %%
#A, b = balancear(X_train, y_train)

# %%
#A.loc[:,('prcp')] = A.loc[:,].apply(f,axis=1)

# %%
#g = A.groupby('rain')
#g.count()

# %%
#b.groupby(pd.cut(b.values, [-50,   0,  49.99, 200])).count()

# %%
#len(A)

# %%
from sklearn.preprocessing import MinMaxScaler

scale = MinMaxScaler()

_X = X_train
for c in ['prcp_plus_12','prcp_acum_24']:
    _X = _X.drop(c,1)
    
scale.fit(_X)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_val.shape
# Out:
# (2773, 327)

# %%
evaluations = []  
STEPS = 500  

for i in range(1, 200):    
    
    A, b = balancear(X_train, y_train)
    
    sc_A = scale.transform(A)
    A = pd.DataFrame(sc_A, columns = A.columns)
    
    C, d = balancear(X_val, y_val)
    
    sc_C = scale.transform(C)
    C = pd.DataFrame(sc_C, columns = C.columns)
    
    print ('treinando agora...')
    
    regressor.train(input_fn=wx_input_fn(A ,b), steps=STEPS)
    
    evaluations.append(
        regressor.evaluate(input_fn=wx_input_fn(C
                                                ,d
                                                ,num_epochs=1
                                                ,shuffle=False)))
# Out:
# /Users/dedeco/Envs/kaggle/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/dedeco/Envs/kaggle/lib/python3.6/site-packages/pandas/core/indexing.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# treinando agora...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tf_model_14/model.ckpt.
# INFO:tensorflow:loss = 421.10602, step = 1
# INFO:tensorflow:global_step/sec: 1.64145
# INFO:tensorflow:loss = 525.74536, step = 101 (60.923 sec)
# INFO:tensorflow:global_step/sec: 1.37473
# INFO:tensorflow:loss = 349.6028, step = 201 (72.743 sec)
# INFO:tensorflow:global_step/sec: 1.45533
# INFO:tensorflow:loss = 559.5727, step = 301 (68.711 sec)
# INFO:tensorflow:global_step/sec: 1.34573
# INFO:tensorflow:loss = 413.65027, step = 401 (74.311 sec)
# INFO:tensorflow:Saving checkpoints for 500 into /tmp/tf_model_14/model.ckpt.
# INFO:tensorflow:Loss for final step: 438.65515.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-18-13:56:47
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tf_model_14/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-18-13:56:48
# INFO:tensorflow:Saving dict for global step 500: average_loss = 0.46904314, global_step = 500, loss = 180.11256
# /Users/dedeco/Envs/kaggle/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# treinando agora...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tf_model_14/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 501 into /tmp/tf_model_14/model.ckpt.
# INFO:tensorflow:loss = 610.352, step = 501
# INFO:tensorflow:global_step/sec: 1.5531
# INFO:tensorflow:loss = 461.76505, step = 601 (64.389 sec)
# INFO:tensorflow:global_step/sec: 1.27005
# INFO:tensorflow:loss = 585.78986, step = 701 (78.737 sec)
# INFO:tensorflow:global_step/sec: 1.24897
# INFO:tensorflow:loss = 437.5907, step = 801 (80.068 sec)
# INFO:tensorflow:global_step/sec: 1.22673
# INFO:tensorflow:loss = 349.97995, step = 901 (81.515 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tf_model_14/model.ckpt.
# INFO:tensorflow:Loss for final step: 331.45892.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-18-14:03:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tf_model_14/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-18-14:03:09
# INFO:tensorflow:Saving dict for global step 1000: average_loss = 0.36248147, global_step = 1000, loss = 139.19289
# treinando agora...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tf_model_14/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1001 into /tmp/tf_model_14/model.ckpt.
# INFO:tensorflow:loss = 500.61, step = 1001
# INFO:tensorflow:global_step/sec: 1.45606
# INFO:tensorflow:loss = 305.65366, step = 1101 (68.680 sec)
# INFO:tensorflow:global_step/sec: 1.3632
# INFO:tensorflow:loss = 445.0282, step = 1201 (73.359 sec)
# INFO:tensorflow:global_step/sec: 1.33345
# INFO:tensorflow:loss = 315.63232, step = 1301 (74.991 sec)
# INFO:tensorflow:global_step/sec: 1.55102
# INFO:tensorflow:loss = 495.41528, step = 1401 (64.474 sec)
# INFO:tensorflow:Saving checkpoints for 1500 into /tmp/tf_model_14/model.ckpt.
# INFO:tensorflow:Loss for final step: 346.05032.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-18-14:09:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tf_model_14/model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-18-14:09:11
# INFO:tensorflow:Saving dict for global step 1500: average_loss = 0.39835116, global_step = 1500, loss = 152.96684
# treinando agora...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tf_model_14/model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1501 into /tmp/tf_model_14/model.ckpt.
# INFO:tensorflow:loss = 512.3235, step = 1501
# INFO:tensorflow:global_step/sec: 1.24242
# INFO:tensorflow:loss = 337.9878, step = 1601 (80.491 sec)
# INFO:tensorflow:global_step/sec: 1.12703
# INFO:tensorflow:loss = 507.4629, step = 1701 (88.727 sec)
# INFO:tensorflow:global_step/sec: 1.20279
# INFO:tensorflow:loss = 458.59644, step = 1801 (83.140 sec)
# INFO:tensorflow:global_step/sec: 1.21049
# INFO:tensorflow:loss = 589.30786, step = 1901 (82.611 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into /tmp/tf_model_14/model.ckpt.
# INFO:tensorflow:Loss for final step:
into /tmp/tf_model_14/model.ckpt.
# INFO:tensorflow:loss = 265.74054, step = 6501
# INFO:tensorflow:global_step/sec: 1.17757
# INFO:tensorflow:loss = 430.13086, step = 6601 (84.923 sec)
# INFO:tensorflow:global_step/sec: 1.00167
# INFO:tensorflow:loss = 367.57916, step = 6701 (99.833 sec)
# INFO:tensorflow:global_step/sec: 1.06544
# INFO:tensorflow:loss = 494.34607, step = 6801 (93.863 sec)
# INFO:tensorflow:global_step/sec: 1.08504
# INFO:tensorflow:loss = 415.98703, step = 6901 (92.159 sec)
# INFO:tensorflow:Saving checkpoints for 7000 into /tmp/tf_model_14/model.ckpt.
# INFO:tensorflow:Loss for final step: 428.79462.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-18-15:54:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tf_model_14/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-18-15:54:37
# INFO:tensorflow:Saving dict for global step 7000: average_loss = 0.32812777, global_step = 7000, loss = 126.00107
# treinando agora...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tf_model_14/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7001 into /tmp/tf_model_14/model.ckpt.
# INFO:tensorflow:loss = 414.5948, step = 7001
# INFO:tensorflow:global_step/sec: 1.18957
# INFO:tensorflow:loss = 270.53052, step = 7101 (84.065 sec)
# INFO:tensorflow:global_step/sec: 0.963515
# INFO:tensorflow:loss = 414.08313, step = 7201 (103.787 sec)
# INFO:tensorflow:global_step/sec: 1.07138
# INFO:tensorflow:loss = 322.9953, step = 7301 (93.338 sec)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-705ca5856d28> in <module>()
#      16     print ('treinando agora...')
#      17
# ---> 18     regressor.train(input_fn=wx_input_fn(A ,b), steps=STEPS)
#      19
#      20     evaluations.append(
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     350
#     351     saving_listeners = _check_listeners_type(saving_listeners)
# --> 352     loss = self._train_model(input_fn, hooks, saving_listeners)
#     353     logging.info('Loss for final step: %s.', loss)
#     354     return self
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#     889         loss = None
#     890         while not mon_sess.should_stop():
# --> 891           _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#     892       return loss
#     893
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1020                               feed_dict=feed_dict,
#    1021                               options=options,
# -> 1022                               run_metadata=run_metadata)
#    1023       except _PREEMPTION_ERRORS as e:
#    1024         logging.info('An error was raised. This may be due to a preemption in '
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1168                                   feed_dict=feed_dict,
#    1169                                   options=options,
# -> 1170                                   run_metadata=run_metadata)
#    1171
#    1172     for hook in self._hooks:
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     948
#     949   def run(self, *args, **kwargs):
# --> 950     return self._sess.run(*args, **kwargs)
#     951
#     952   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# ~/Envs/kaggle/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt  
# %matplotlib inline

plt.rcParams['figure.figsize'] = [15, 10]

loss_values = [ev['loss'] for ev in evaluations]  
training_steps = [ev['global_step'] for ev in evaluations]

plt.scatter(x=training_steps, y=loss_values)  
plt.xlabel('Training steps')  
plt.ylabel('Loss (SSE)')  
plt.show()

# %%
X_test = X_test.drop('prcp_plus_12',1)
X_test = X_test.drop('prcp_acum_24',1)

# %%
sc_X_test = scale.transform(X_test)
C = pd.DataFrame(sc_X_test, columns = X_test.columns)

# %%
pred = regressor.predict(input_fn=wx_input_fn(C,  
                                              num_epochs=1,
                                              shuffle=False))

predictions = np.array([p['predictions'][0] for p in pred])
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tf_model_14/model.ckpt-7001
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
predictions
# Out:
# array([1.5759331, 1.3786021, 1.4686575, ..., 1.1885334, 1.2842104,
#        1.5971091], dtype=float32)

# %%
print("The Explained Variance: %.2f" % explained_variance_score(  
                                            y_test, predictions))  
print("The Mean Absolute Error: %.2f " % mean_absolute_error(  
                                            y_test, predictions))  
print("The Median Absolute Error: %.2f " % median_absolute_error(  
                                            y_test, predictions))
# Out:
# The Explained Variance: 0.03
# The Mean Absolute Error: 8.89
# The Median Absolute Error: 0.97

# %%
predictions
# Out:
# array([1.5759331, 1.3786021, 1.4686575, ..., 1.1885334, 1.2842104,
#        1.5971091], dtype=float32)

# %%
predictions.size
# Out:
# 2772

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, predictions, edgecolors=(0, 0, 0))
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=1)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()
